# %%
# 30 Days of Python.
#Every Python file has an extension .py

# %% [markdown]
# #Data Types.
# """This is a multiline comment"""
# 1.Number
# integer
# float
# complex example
# 2.String
# 3.Boolean:T and F are always upper case.
# 4.List - ordered collection that stores different data types.[]
# 5.Dictionary - unordered collection in key pair format.
# 6.Tuple  immutable
# 7.Set

# %%
type(10)
# Out:
# int

# %%
type("Winny")
# Out:
# str

# %%
# !python --version
# Out:
# Python 3.13.5
